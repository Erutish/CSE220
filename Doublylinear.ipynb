# %%
class Node:
  def __init__(self, e, n, p):
    self.element = e
    self.next = n
    self.prev = p
class DoublyList:
  
  def __init__(self, a):
  #  Design the constructor based on data type of a. If 'a' is built in python list then
  #  Creates a linked list using the values from the given array.
    if type(a)==list:
        self.head = Node(None,None,None)
        self.temp=self.head
        for i in range(len(a)):
            newNode=Node(a[i],None,None)
            if self.head==None:
                self.head=self.temp=newNode
                self.head.prev=None
                self.temp.next=None
            else:
                self.temp.next=newNode
                newNode.prev=self.temp
                self.temp=newNode
                self.temp.next=None
            #print(self.temp.element)
    else:
        self.head=a

      # Counts the number of Nodes in the list
  def countNode(self):
    count=0
    temp=self.head.next
    while (temp!=None):
        count+=1
        temp=temp.next
    return count


  
  # prints the elements in the list
  def forwardprint(self):
    # To Do
    temp=self.head.next        #10node
    while (temp.next!=None):    #10,20,30
        print(temp.element,end=",")
        temp=temp.next         #10node=>20node
    print(str(temp.element)+".")

  # prints the elements in the list backward
  def backwardprint(self):
    # To Do
    temp=self.temp
    #print(self.temp.prev.element)
    while (temp.prev.prev!=None):
        print(temp.element,end=",")    
        temp=temp.prev
    print(str(temp.element)+".")

  # returns the reference of the at the given index. For invalid index return None.
  def nodeAt(self, idx):
    # To Do
    count=self.countNode()
    if (idx>=count or idx<0):
        return None
    else:
        temp=self.head.next
        count=0
        while(temp!=None):
            if count==idx:
                return temp
            count+=1
            temp=temp.next
    return Node("Index Error",None,None)
  
  # returns the index of the containing the given element. if the element does not exist in the List, return -1.
  def indexOf(self, elem):
    # To Do
    count=0
    n=self.head.next
    while(n!=None):
      if(n.element==elem):
        return count
      count+=1
      n=n.next
    return -1

  # inserts containing the given element at the given index Check validity of index. 
  def insert(self, elem, idx):
    # To Do
    count=self.countNode()
    if(idx>count or idx<0):
      return None
    elif(idx==count):
      n=self.nodeAt(idx-1)
      newNode=Node(elem,None,None)
      n.next=newNode
      newNode.prev=n
      newNode.next=None
    else:
      n=self.nodeAt(idx)
      pred=n.prev
      newNode=Node(elem,None,None)
      pred.next=newNode
      newNode.next=n
      newNode.prev=n.prev
      n.prev=newNode

  # removes at the given index. returns element of the removed node. Check validity of index. return None if index is invalid.
  def remove(self, idx):
    # To Do

            
        if ((idx < 0) or (idx > self.countNode() - 1)):
            return None
        elif idx==0:
            output=self.head
            self.head=self.head.next
            self.head.prev=None
        
        else:
            h = self.head.next
            index = 0
            
            while (idx > index):
                h = h.next
                index += 1
            
            output = str(h.element)
            
            p = h.prev
            node = h.next
            p.next = node
            node.prev = p
            h = None
            
        return output

# %%
a1 = [10, 20, 30, 40]
h1 = DoublyList(a1)
h1.forwardprint() # This should print: 10,20,30,40. 
h1.backwardprint() # This should print: 40,30,20,10. 
print(h1.countNode()) # This should print: 4

print("///  Test 02  ///")
# returns the reference of the at the given index. For invalid idx return None.
myNode = h1.nodeAt(2)
print(myNode.element) # This should print: 30. In case of invalid index This will print "index error"

print("///  Test 03  ///")
# returns the index of the containing the given element. if the element does not exist in the List, return -1.
index = h1.indexOf(40)
print(index) # This should print: 3. In case of element that 
#doesn't exists in the list this will print -1.

print("///  Test 04  ///")

a2 = [10, 20, 30, 40]
h2 = DoublyList(a2) # uses the  constructor
h2.forwardprint() # This should print: 10,20,30,40.  

# inserts containing the given element at the given index. Check validity of index.
h2.insert(85,0)
h2.forwardprint() # This should print: 85,10,20,30,40. 
h2.backwardprint() # This should print: 40,30,20,10,85.

print()
h2.insert(95,3)
h2.forwardprint() # This should print: 85,10,20,95,30,40.  
h2.backwardprint() # This should print: 40,30,95,20,10,80.  

print()
h2.insert(75,6)
h2.forwardprint() # This should print: 85,10,20,95,30,40,75. 
h2.backwardprint() # This should print: 75,40,30,95,20,10,85.
# Out:
# 10,20,30,40.
# 40,30,20,10.
# 4
# ///  Test 02  ///
# 30
# ///  Test 03  ///
# 3
# ///  Test 04  ///
# 10,20,30,40.
# 85,10,20,30,40.
# 40,30,20,10,85.
#
# 85,10,20,95,30,40.
# 40,30,95,20,10,85.
#
# 85,10,20,95,30,40,75.
# 40,30,95,20,10,85.

# %%
class Node():
    def __init__(self,e,n,p):
        self.element=e
        self.next=n
        self.prev=p
class DoublylinearList():
    def __init__(self,a):
        self.head=Node(a[0],None,None)
        temp=self.head
        for i in range(1,len(a)):
            newNode=Node(a[i],None,temp)
            temp.next=newNode
            temp=temp.next
    def palindrome(self):
        temp=self.head
        c=1
        while temp.next!=None:
            temp=temp.next
            c+=1
        last=temp
        temp=self.head
        f=True
        while temp.next!=None:
            if temp.element!=last.element:
                f=False
                break
            temp=temp.next
            last=last.prev
        print(f)


a1 = [1,7,7,1]
h1 = DoublylinearList(a1) 
h1.palindrome() 
a2=[3,4,5,3]
h2 = DoublylinearList(a2) 
h2.palindrome()
# Out:
# True
# False

# %%
class Node():
    def __init__(self,e,n,p):
        self.element=e
        self.next=n
        self.prev=p
class DoublylinList():
    def __init__(self,a):
        self.head=Node(a[0],None,None)
        temp=self.head
        for i in range(1,len(a)):
            newNode=Node(a[i],None,temp)
            temp.next=newNode
            temp=temp.next
    def reverse(self):
        temp=self.head
        copy_head=Node(temp.element,None,None)
        while temp.next!=None:
            newNode=Node(temp.next.element,copy_head,None)
            copy_head.prev=newNode
            copy_head=copy_head.prev
            temp=temp.next


        temp_copy=copy_head

        while temp_copy.next!=None:
            #print(temp_copy.next.element) 40->30,30->20,20->10,10->None stop
                                #printing   40   , 30   ,  20,
            print(temp_copy.element,end=" ,")
            temp_copy=temp_copy.next
        print(temp_copy.element,end=".")

a3 = [10, 20, 30, 40]
h3 = DoublylinList(a3)
h3.reverse()
# Out:
# 40 ,30 ,20 ,10.
